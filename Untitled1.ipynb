# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('DATA_HAPPINESS.csv')
data.head(6)
# Out:
#   Country name Regional indicator  Healthy life expectancy  \
# 0      Finland     Western Europe                     72.0
# 1      Denmark     Western Europe                     72.7
# 2  Switzerland     Western Europe                     74.4
# 3      Iceland     Western Europe                     73.0
# 4  Netherlands     Western Europe                     72.4
# 5       Norway     Western Europe                     73.3
#
#    Freedom to make life choices
# 0                         0.949
# 1                         0.946
# 2                         0.919
# 3                         0.955
# 4                         0.913
# 5                         0.960

# %%
data = df.head(6)
data
# Out:
#   Country name Regional indicator  Healthy life expectancy  \
# 0      Finland     Western Europe                     72.0
# 1      Denmark     Western Europe                     72.7
# 2  Switzerland     Western Europe                     74.4
# 3      Iceland     Western Europe                     73.0
# 4  Netherlands     Western Europe                     72.4
# 5       Norway     Western Europe                     73.3
#
#    Freedom to make life choices
# 0                         0.949
# 1                         0.946
# 2                         0.919
# 3                         0.955
# 4                         0.913
# 5                         0.960

# %%
CN=data["Country name"]
RI=data["Healthy life expectancy"]
FC=data["Freedom to make life choices"]
x=[]
y=[]
z=[]
x=list(CN)
y=list(RI)
z=list(FC)

# %%
plt.scatter(x,y)
plt.xlabel('Country name')
plt.ylabel('Healthy life expectancy')
plt.title('Data')
plt.show()

plt.scatter(x,z)
plt.xlabel('Country name')
plt.ylabel('Freedom to make life choices')
plt.title('Data')
plt.show()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(x,z)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.pie(z,labels=x,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7d68267a60>,
# ...
#  [Text(0.9499626870451229, 0.5545907439022131, 'Finland'),
#   Text(-0.014087127461835516, 1.099909793046627, 'Denmark'),
#   Text(-0.9548657754325185, 0.5461056224831009, 'Switzerland'),
#   Text(-0.9524237964430713, -0.5503534427701595, 'Iceland'),
#   Text(-0.007350249623949298, -1.099975442376086, 'Netherlands'),
#   Text(0.9465478284110371, -0.5603991510792551, 'Norway')],
#  [Text(0.5181614656609761, 0.30250404212847987, '16.82%'),
#   Text(-0.0076838877064557345, 0.5999507962072511, '16.77%'),
#   Text(-0.5208358775086465, 0.2978757940816914, '16.29%'),
#   Text(-0.519503888968948, -0.3001927869655415, '16.93%'),
#   Text(-0.0040092270676087075, -0.5999866049324104, '16.18%'),
#   Text(0.5162988154969294, -0.30567226422504823, '17.02%')])

# %%
data.plot(x="Country name", y=["Healthy life expectancy", "Freedom to make life choices"], kind="bar")
# Out:
# <AxesSubplot:xlabel='Country name'>

# %%
plt.pie(z,labels=x,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7d6854a760>,
# ...
#  [Text(0.9499626870451229, 0.5545907439022131, 'Finland'),
#   Text(-0.014087127461835516, 1.099909793046627, 'Denmark'),
#   Text(-0.9548657754325185, 0.5461056224831009, 'Switzerland'),
#   Text(-0.9524237964430713, -0.5503534427701595, 'Iceland'),
#   Text(-0.007350249623949298, -1.099975442376086, 'Netherlands'),
#   Text(0.9465478284110371, -0.5603991510792551, 'Norway')],
#  [Text(0.5181614656609761, 0.30250404212847987, '16.82%'),
#   Text(-0.0076838877064557345, 0.5999507962072511, '16.77%'),
#   Text(-0.5208358775086465, 0.2978757940816914, '16.29%'),
#   Text(-0.519503888968948, -0.3001927869655415, '16.93%'),
#   Text(-0.0040092270676087075, -0.5999866049324104, '16.18%'),
#   Text(0.5162988154969294, -0.30567226422504823, '17.02%')])

# %%
plt.pie(z,labels=x,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7d682cf220>,
# ...
#  [Text(0.9499626870451229, 0.5545907439022131, 'Finland'),
#   Text(-0.014087127461835516, 1.099909793046627, 'Denmark'),
#   Text(-0.9548657754325185, 0.5461056224831009, 'Switzerland'),
#   Text(-0.9524237964430713, -0.5503534427701595, 'Iceland'),
#   Text(-0.007350249623949298, -1.099975442376086, 'Netherlands'),
#   Text(0.9465478284110371, -0.5603991510792551, 'Norway')],
#  [Text(0.5181614656609761, 0.30250404212847987, '16.82%'),
#   Text(-0.0076838877064557345, 0.5999507962072511, '16.77%'),
#   Text(-0.5208358775086465, 0.2978757940816914, '16.29%'),
#   Text(-0.519503888968948, -0.3001927869655415, '16.93%'),
#   Text(-0.0040092270676087075, -0.5999866049324104, '16.18%'),
#   Text(0.5162988154969294, -0.30567226422504823, '17.02%')])
