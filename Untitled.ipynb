# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('vaccine_doses.csv')

# %%
data
# Out:
#     report_date previous_day_doses_administered total_doses_administered  \
# 0    2020-12-24                             NaN                   10,756
# 1    2020-12-30                           4,595                   18,603
# 2    2020-12-31                           5,463                   23,502
# 3    2021-01-01                           5,415                   28,887
# 4    2021-01-02                           4,305                   33,191
# ..          ...                             ...                      ...
# 96   2021-04-04                          69,125                2,493,188
# 97   2021-04-05                          52,452                2,545,640
# 98   2021-04-06                          76,199                2,621,839
# 99   2021-04-07                         104,382                2,726,221
# 100  2021-04-08                         108,563                2,834,784
#
#     total_doses_in_fully_vaccinated_individuals   \
# ...

# %%
report_date = data["report_date"]
previous_day_doses_administered = data["previous_day_doses_administered"]
total_doses_administered=data['total_doses_administered']
total_doses_in_fully_vaccinated_individuals=data['total_doses_in_fully_vaccinated_individuals']
total_individuals_fully_vaccinated=data['total_individuals_fully_vaccinated']
a=[]
b=[]
c=[]
d=[]
e=[]
x=list(report_date)
y=list(previous_day_doses_administered)
# Out:
# ['2020-12-24',
#  '2020-12-30',
#  '2020-12-31',
#  '2021-01-01',
#  '2021-01-02',
#  '2021-01-03',
#  '2021-01-04',
#  '2021-01-05',
#  '2021-01-06',
#  '2021-01-07',
#  '2021-01-08',
#  '2021-01-09',
#  '2021-01-10',
#  '2021-01-11',
#  '2021-01-12',
#  '2021-01-13',
#  '2021-01-14',
#  '2021-01-15',
#  '2021-01-16',
#  '2021-01-17',
#  '2021-01-18',
#  '2021-01-19',
#  '2021-01-20',
#  '2021-01-21',
#  '2021-01-22',
#  '2021-01-23',
#  '2021-01-24',
#  '2021-01-25',
#  '2021-01-26',
#  '2021-01-27',
#  '2021-01-28',
#  '2021-01-29',
#  '2021-01-30',
#  '2021-01-31',
#  '2021-02-01',
#  '2021-02-02',
#  '2021-02-03',
#  '2021-02-04',
#  '2021-02-05',
#  '2021-02-06',
#  '2021-02-07',
#  '2021-02-08',
#  '2021-02-09',
#  '2021-02-10',
#  '2021-02-11',
#  '2021-02-12',
#  '2021-02-13',
#  '2021-02-14',
#  '2021-02-15',
#  '2021-02-16',
#  '2021-02-17',
#  '2021-02-18',
#  '2021-02-19',
#  '2021-02-20',
#  '2021-02-21',
#  '2021-02-22',
#  '2021-02-23',
#  '2021-02-24',
# ...
